# %%
# Parameters
GROUP_ID = 'Group27'
ALGORITHM = 'ValItr' # ValItr, QLrng, or SARSA
TRACK_NAME = 'provided/U-track.txt' # 2-track, U-track, or W-track
CRASH_POS = 'STRT' # NRST or STRT. Determines whether car must re-start on crash

# %%
from CSCI446_Project4_main_Group27 import main

main(GROUP_ID, ALGORITHM, TRACK_NAME, CRASH_POS)
# Out:
# 25,25
# #########################
# #SSSS###############FFFF#
# #....###############....#
# #....###############....#
# #....###############....#
# #....###############....#
# #....###############....#
# #....###############....#
# #....###############....#
# #....###############....#
# #....###############....#
# #....###############....#
# #....###############....#
# #....###############....#
# #....###############....#
# #....###############....#
# #....###############....#
# #....###############....#
# ##....#############....##
# ###....###########....###
# ###...................###
# ####.................####
# #####...............#####
# ######.............######
# #########################
#
# run Value Iteration
# k: 2
# k: 3
# k: 4
# k: 5
# k: 6
# k: 7
# k: 8
# k: 9
# k: 10
# k: 11
# k: 12
# k: 13
# k: 14
# k: 15
# k: 16
# k: 17
# k: 18
# k: 19
# k: 20
# k: 21
# k: 22
# k: 23
# k: 24
# k: 25
# k: 26
# k: 27
# k: 28
# k: 29
# k: 30
# k: 31
# k: 32
# Moves of Best Run: 16
# ...
